# %%
#Importing all relevant libraries
import pandas as pd
import numpy as rp
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import datetime as dt

# %%
#Load Dataset from the table using spark
df = spark.table('workspace.default.retail_sales_dataset')
rs = df.toPandas()

# %%
#Summary of our table/data
rs.info()

# %%
#Describing the table
rs.describe()

# %%
#Listing the table column
rs.columns

# %%
#Displaying the entire table
display(rs)

# %%
#Summary of the data
print(rs)

# %%
#Show First 5 rows
rs.head()

# %%
#Show Last 5 rows
rs.tail()

# %%
rs.duplicated().sum()

# %%
#Checking for null variables in our table/data
rs.isnull().sum()

# %%
#Checking the shape
rs.shape

# %%
#Deleting rows that has missing (null) values
rs = rs.dropna()

# %%
#Replacing missing (null) values with 0
rs = rs.fillna(0)

# %%
#Checking the data types of our table
rs.dtypes

# %%
display(rs)

# %%
#Converting the date datatypes from object
print(pd.DatetimeIndex(rs['Date']))

# %%
rs.dtypes

# %%
date_column = pd.DatetimeIndex(rs['Date'])
rs['Year'] = date_column.year
rs['Month'] = date_column.month
rs['Day'] = date_column.day

# %%
display(rs)

# %%
#Sta
rs.groupby('Month')['Total Amount'].sum()

# %%
#29 APRIL 2026
#Create a graph (Sales (Total Amount) by Category - Matplotlib)
sales_by_category = rs.groupby('Product Category')['Total Amount'].sum()
plt.figure()
sales_by_category.plot(kind='bar')
plt.title('Total Sales by Category')
plt.xlabel('Category')
plt.ylabel('Sales')
plt.show()

# %%
# Sales (Total Amount) Trend Over Time
rs['Date'] = pd.to_datetime(rs['Date'])
sales_trend = rs.groupby('Date')['Total Amount'].sum()
plt.figure()
sales_trend.plot()
plt.title('Sales Trend Over Time')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.show()

# %%
# Seaborn - Sales (Total Amount) by Region (Month)
plt.figure()
sns.barplot(data=rs, x='Month', y='Total Amount')
plt.title('Sales by Month')
plt.show()

# %%
#30 APRIL 2026
#Plot Histogram
plt.figure()
plt.hist(rs['Total Amount'], bins=10) #Type of Graph'hist'
plt.title('Distribution of Sales Amount')
plt.xlabel('Sales Amount')
plt.ylabel('Frequency')
plt.show()

# %%
#Plot Pie Chart
sales_by_category = rs.groupby('Product Category')['Total Amount'].sum()
plt.figure()
sales_by_category.plot(kind='pie', autopct='%1.1f%%')
plt.title('Sales Contribution by Category')
plt.ylabel('')
plt.show()

# %%
sales_trend = rs.groupby('Date')['Total Amount'].sum()
plt.figure()
plt.plot(sales_trend, marker='o')
plt.title('Sales Trend with Markers')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.show()

# %%
#To increase the SIZE of the above graph (added 'figsize')
#Note! figsize '10=width' and '5=height'
sales_trend = rs.groupby('Date')['Total Amount'].sum()
plt.figure(figsize=(10,5))
plt.plot(sales_trend, marker='o')
plt.title('Sales Trend with Markers')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.show()

# %%
#To change COLOURS
#Sales Trend Over Time
rs['Date'] = pd.to_datetime(rs['Date'])
sales_trend = rs.groupby('Date')['Total Amount'].sum()
plt.figure(figsize=(12,6)) #Size extension
sales_trend.plot(color='green') #Colour inserted here
plt.title('Sales Trend Over Time')
plt.xlabel('Date')
plt.ylabel('Sales')
plt.show()
